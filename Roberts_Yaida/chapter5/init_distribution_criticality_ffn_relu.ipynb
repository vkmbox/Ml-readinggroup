# %%
import torch
import numpy as np
from common.ffn.ffn_relu import ParametricReLUNet

# %%
def sample_covariance(neuron_one, trainpoint_one, neuron_two, trainpoint_two, yy):
    '''Sample covariance, formulas as in https://en.wikipedia.org/wiki/Sample_mean_and_covariance'''
    one = yy[:, neuron_one-1, trainpoint_one-1]
    two = yy[:, neuron_two-1, trainpoint_two-1]
    cov = np.cov(one, two)[0, 1]

    return cov

# %%
#Test for PReLU-activation implementation
testPReLU = ParametricReLUNet()
testPReLU.set_slopes(0.5, 0.2)
resultPReLU = testPReLU.PReLU(torch.tensor(np.array([1.1,-2.2]), dtype=torch.float32))
print(resultPReLU)
# Out:
# FeedForwardNet created with n0=3, nk=10, nl=3, l=3, bias_on=False
# tensor([ 0.5500, -0.4400])

# %%
'''n0: # dimension of x
    nk: # hidden nodes
    nl: # dimension of y
    l: # number of layers
    nd: # number of points in train-set'''
n0,nk,nl,l=3,10000,2,20
nd = 2
'''slope_plus, slope_minus: # slopes for Relu
    experiments_number: # number of experiments'''
slope_plus, slope_minus=1.0, 0.5
experiments_number = 200

testNet = ParametricReLUNet(n0=n0,nk=nk,nl=nl,l=l)
testNet.set_log_level("info")
testNet.set_slopes(slope_plus, slope_minus)
testNet.set_gmetric_recording_indices([(1,1),(1,2),(2,2)])

xx = np.random.normal(size=(n0, nd)).astype(np.float32)
yy = np.zeros((experiments_number, nl, nd))
#weights distribution variances are set as in (5.67)
cb, cw = 0, 2.0/(slope_plus**2.0 + slope_minus**2.0)

G01_records = []
G00_records = []
G11_records = []

#for each experiment re-initialisation of the weights with recalculation
for experiment_number in range(experiments_number):
    testNet.init_weights(cb, cw)
    res = testNet.forward(xx)
    yy[experiment_number] = res
    G00_records.append(testNet.get_gmetric(1,1).copy())
    G11_records.append(testNet.get_gmetric(2,2).copy())
    G01_records.append(testNet.get_gmetric(1,2).copy())
    
    print('-', end='')
# Out:
# FeedForwardNet created with n0=3, nk=10000, nl=2, l=20, bias_on=False
# --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Projects-my\ml\Ml-readinggroup\Roberts_Yaida\chapter5\init_distribution_criticality_ffn_relu.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/d%3A/Projects-my/ml/Ml-readinggroup/Roberts_Yaida/chapter5/init_distribution_criticality_ffn_relu.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> #for each experiment re-initialisation of the weights with recalculation
#      <a href='vscode-notebook-cell:/d%3A/Projects-my/ml/Ml-readinggroup/Roberts_Yaida/chapter5/init_distribution_criticality_ffn_relu.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> for experiment_number in range(experiments_number):
# ---> <a href='vscode-notebook-cell:/d%3A/Projects-my/ml/Ml-readinggroup/Roberts_Yaida/chapter5/init_distribution_criticality_ffn_relu.ipynb#W4sZmlsZQ%3D%3D?line=28'>29</a>     testNet.init_weights(cb, cw)
#      <a href='vscode-notebook-cell:/d%3A/Projects-my/ml/Ml-readinggroup/Roberts_Yaida/chapter5/init_distribution_criticality_ffn_relu.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a>     res = testNet.forward(xx)
#      <a href='vscode-notebook-cell:/d%3A/Projects-my/ml/Ml-readinggroup/Roberts_Yaida/chapter5/init_distribution_criticality_ffn_relu.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a>     yy[experiment_number] = res
#
# File d:\Projects-my\ml\Ml-readinggroup\Roberts_Yaida\chapter5\ffn_base.py:49, in init_weights(self, cb, cw)
#
# File d:\Projects-my\ml\Ml-readinggroup\Roberts_Yaida\chapter5\ffn_base.py:56, in init_linear_weights(linear, bias_on, std_b, std_w)
#
# File d:\Programs-python\Python39\lib\site-packages\torch\nn\init.py:155, in normal_(tensor, mean, std)
#     153 if torch.overrides.has_torch_function_variadic(tensor):
#     154     return torch.overrides.handle_torch_function(normal_, (tensor,), tensor=tensor, mean=mean, std=std)
# --> 155 return _no_grad_normal_(tensor, mean, std)
#
# File d:\Programs-python\Python39\lib\site-packages\torch\nn\init.py:19, in _no_grad_normal_(tensor, mean, std)
#      17 def _no_grad_normal_(tensor, mean, std):
#      18     with torch.no_grad():
# ---> 19         return tensor.normal_(mean, std)
#
# KeyboardInterrupt:

# %%
for trainpoint1 in range(1, nd+1):
    for trainpoint2 in range(trainpoint1, nd+1):
        print("Metric (4.8) for trainpoint {} and trainpoint {}: {}"\
              .format(trainpoint1, trainpoint2, ParametricReLUNet.G_xx(xx[:,trainpoint1-1], xx[:,trainpoint2-1], cb, cw)))
# Out:
# Metric (4.8) for trainpoint 1 and trainpoint 1: 0.6586294174194336
# Metric (4.8) for trainpoint 1 and trainpoint 2: 0.04059592882792155
# Metric (4.8) for trainpoint 2 and trainpoint 2: 0.7603687922159831

# %%
for neuron1 in range(1, nl+1):
      for neuron2 in range(neuron1, nl+1):
            for trainpoint1 in range(1, nd+1):
                  for trainpoint2 in range(1 if neuron1 != neuron2 else trainpoint1, nd+1):
                        print("Sample covariance between neuron {}, trainpoint {} and neuron {}, trainpoint {}: {}"\
                              .format(neuron1, trainpoint1, neuron2, trainpoint2\
                                      , sample_covariance(neuron1,trainpoint1,neuron2,trainpoint2,yy)))
# Out:
# Sample covariance between neuron 1, trainpoint 1 and neuron 1, trainpoint 1: 0.6371224152636515
# Sample covariance between neuron 1, trainpoint 1 and neuron 1, trainpoint 2: 0.45520974026600336
# Sample covariance between neuron 1, trainpoint 2 and neuron 1, trainpoint 2: 0.7613337725503131
# Sample covariance between neuron 1, trainpoint 1 and neuron 2, trainpoint 1: 0.019775779264012087
# Sample covariance between neuron 1, trainpoint 1 and neuron 2, trainpoint 2: -0.008006102920478956
# Sample covariance between neuron 1, trainpoint 2 and neuron 2, trainpoint 1: -0.07709782794924805
# Sample covariance between neuron 1, trainpoint 2 and neuron 2, trainpoint 2: -0.050339967884426164
# Sample covariance between neuron 2, trainpoint 1 and neuron 2, trainpoint 1: 0.6298608782647537
# Sample covariance between neuron 2, trainpoint 1 and neuron 2, trainpoint 2: 0.4156670109758191
# Sample covariance between neuron 2, trainpoint 2 and neuron 2, trainpoint 2: 0.6236863611866437

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
for i, Gs in enumerate(G01_records):
    plt.plot(Gs, label=f"experiment {i}")
#plt.legend()
plt.title("G01")
# Out:
# Text(0.5, 1.0, 'G01')

# %%
plt.figure(figsize=(12, 8))
for i, Gs in enumerate(G00_records):
    plt.plot(Gs, label=f"experiment {i}")
#plt.legend()
plt.title("G00")
# Out:
# Text(0.5, 1.0, 'G00')

# %%
plt.figure(figsize=(12, 8))
for i, Gs in enumerate(G11_records):
    plt.plot(Gs, label=f"experiment {i}")
#plt.legend()
plt.title("G11")
# Out:
# Text(0.5, 1.0, 'G11')
